# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = (10, 4)

# %%
df = pd.read_csv("Air_Traffic_Passenger_Statistics.csv")

# %% [markdown]
# SUMMARY San Francisco International Airport Report on Monthly Passenger Traffic Statistics by Airline.
# https://catalog.data.gov/dataset/air-traffic-passenger-statistics

# %%
df
# Out:
#        Activity Period Activity Period Start Date  \
# 0               199907                 1999/07/01
# 1               199907                 1999/07/01
# 2               199907                 1999/07/01
# 3               199907                 1999/07/01
# 4               199907                 1999/07/01
# ...                ...                        ...
# 34729           202308                 2023/08/01
# 34730           202308                 2023/08/01
# 34731           202308                 2023/08/01
# 34732           202308                 2023/08/01
# 34733           202308                 2023/08/01
#
#                              Operating Airline Operating Airline IATA Code  \
# 0                                 ATA Airlines                          TZ
# 1                                 ATA Airlines                          TZ
# 2                                 ATA Airlines                          TZ
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34734 entries, 0 to 34733
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              34734 non-null  int64
#  1   Activity Period Start Date   34734 non-null  object
#  2   Operating Airline            34734 non-null  object
#  3   Operating Airline IATA Code  34418 non-null  object
#  4   Published Airline            34734 non-null  object
#  5   Published Airline IATA Code  34418 non-null  object
#  6   GEO Summary                  34734 non-null  object
#  7   GEO Region                   34734 non-null  object
#  8   Activity Type Code           34734 non-null  object
#  9   Price Category Code          34734 non-null  object
#  10  Terminal                     34734 non-null  object
#  11  Boarding Area                34734 non-null  object
#  12  Passenger Count              34734 non-null  int64
# ...

# %%
df["Passenger Count"].max()
# Out:
# 856501

# %%
df["Passenger Count"].min()
# Out:
# 0

# %%
df["Passenger Count"].mean()
# Out:
# 27982.63804917372

# %%
df["Passenger Count"].sum()
# Out:
# 971948950

# %%
df["Operating Airline"].describe()
# Out:
# count                                34734
# unique                                 134
# top       United Airlines - Pre 07/01/2013
# freq                                  3670
# Name: Operating Airline, dtype: object

# %%
df["GEO Region"].value_counts().plot(kind="pie" )
# Out:
# <Axes: ylabel='GEO Region'>

# %%
df[df["GEO Region"]=="US"]["Passenger Count"].sum()
# Out:
# 747120929

# %%
df[df["GEO Region"]=="Asia"]["Passenger Count"].sum()
# Out:
# 92685649

# %%
df[df["GEO Region"]=="Europe"]["Passenger Count"].sum()
# Out:
# 62543779

# %%
df[df["GEO Region"]=="Canada"]["Passenger Count"].sum()
# Out:
# 30222011

# %%
df[df["GEO Region"]=="Mexico"]["Passenger Count"].sum()
# Out:
# 19678219

# %%
df[df["GEO Region"]=="Australia / Oceania"]["Passenger Count"].sum()
# Out:
# 10309760

# %%
df[df["GEO Region"]=="Central America"]["Passenger Count"].sum()
# Out:
# 3918042

# %%
df[df["GEO Region"]=="Middle East"]["Passenger Count"].sum()
# Out:
# 5219739

# %%
df[df["GEO Region"]=="South America"]["Passenger Count"].sum()
# Out:
# 250822

# %%
df["GEO Summary"].value_counts().plot(kind="pie", )
# Out:
# <Axes: ylabel='GEO Summary'>

# %%
df[df["GEO Summary"]=="International"]["Passenger Count"].sum()
# Out:
# 224828021

# %%
df[df["GEO Summary"]=="Domestic"]["Passenger Count"].sum()
# Out:
# 747120929

# %%
df["Price Category Code"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["Price Category Code"]["Low Fare"].value_counts().plot(kind="bar")

# %%
df.plot(y="Passenger Count")
# Out:
# <Axes: >

# %%
df.plot(x="Activity Period", y="Passenger Count")
# Out:
# <Axes: xlabel='Activity Period'>

# %%
df.sort_values(by=["Passenger Count"])
# Out:
#        Activity Period Activity Period Start Date  \
# 5244            200306                 2003/06/01
# 6806            200409                 2004/09/01
# 34532           202307                 2023/07/01
# 27533           201811                 2018/11/01
# 24197           201701                 2017/01/01
# ...                ...                        ...
# 373             199909                 1999/09/01
# 116             199907                 1999/07/01
# 117             199907                 1999/07/01
# 244             199908                 1999/08/01
# 243             199908                 1999/08/01
#
#                       Operating Airline Operating Airline IATA Code  \
# 5244                   Midwest Airlines                          YX
# 6806                  Frontier Airlines                          F9
# 34532                  SkyWest Airlines                          OO
# 27533                           WOW Air                          WW
# ...

# %%
df.sort_values(by=["Passenger Count"],ascending=False)
# Out:
#        Activity Period Activity Period Start Date  \
# 243             199908                 1999/08/01
# 244             199908                 1999/08/01
# 117             199907                 1999/07/01
# 116             199907                 1999/07/01
# 373             199909                 1999/09/01
# ...                ...                        ...
# 23245           201606                 2016/06/01
# 25510           201710                 2017/10/01
# 9727            200611                 2006/11/01
# 5244            200306                 2003/06/01
# 6806            200409                 2004/09/01
#
#                       Operating Airline Operating Airline IATA Code  \
# 243    United Airlines - Pre 07/01/2013                          UA
# 244    United Airlines - Pre 07/01/2013                          UA
# 117    United Airlines - Pre 07/01/2013                          UA
# 116    United Airlines - Pre 07/01/2013                          UA
# ...

# %%
df.sort_values(by=["Passenger Count"],ascending=False).iloc[:10]
# Out:
#       Activity Period Activity Period Start Date  \
# 243            199908                 1999/08/01
# 244            199908                 1999/08/01
# 117            199907                 1999/07/01
# 116            199907                 1999/07/01
# 373            199909                 1999/09/01
# 1451           200006                 2000/06/01
# 372            199909                 1999/09/01
# 1572           200007                 2000/07/01
# 1571           200007                 2000/07/01
# 1450           200006                 2000/06/01
#
#                      Operating Airline Operating Airline IATA Code  \
# 243   United Airlines - Pre 07/01/2013                          UA
# 244   United Airlines - Pre 07/01/2013                          UA
# 117   United Airlines - Pre 07/01/2013                          UA
# 116   United Airlines - Pre 07/01/2013                          UA
# 373   United Airlines - Pre 07/01/2013                          UA
# ...

# %%
df.sort_values(by=["Passenger Count"],ascending=False).iloc[:10].describe()
# Out:
#        Activity Period  Passenger Count
# count        10.000000        10.000000
# mean     199947.400000    759811.100000
# std          50.870642     56617.117668
# min      199907.000000    706556.000000
# 25%      199908.000000    719491.750000
# 50%      199909.000000    730843.500000
# 75%      200006.000000    790919.250000
# max      200007.000000    856501.000000

# %%
df["Activity Period"].value_counts().plot(kind="hist",y="Passenger Count",bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="scatter", x="Activity Period", y="Passenger Count" )
# Out:
# <Axes: xlabel='Activity Period', ylabel='Passenger Count'>

# %%
df[df["Passenger Count"]<2000]
# Out:
#        Activity Period Activity Period Start Date  \
# 3               199907                 1999/07/01
# 4               199907                 1999/07/01
# 9               199907                 1999/07/01
# 17              199907                 1999/07/01
# 20              199907                 1999/07/01
# ...                ...                        ...
# 34709           202308                 2023/08/01
# 34710           202308                 2023/08/01
# 34715           202308                 2023/08/01
# 34716           202308                 2023/08/01
# 34719           202308                 2023/08/01
#
#                              Operating Airline Operating Airline IATA Code  \
# 3      Aeroflot Russian International Airlines                         NaN
# 4      Aeroflot Russian International Airlines                         NaN
# 9                                   Air Europe                          PE
# ...

# %%
df2000=df[df["Passenger Count"]<2000]

# %%
df2000["GEO Region"].value_counts().plot(kind="bar", y="Passenger Count")
# Out:
# <Axes: >

# %%
df2000["Operating Airline"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df2000["Operating Airline"].value_counts()>200
# Out:
# United Airlines - Pre 07/01/2013     True
# United Airlines                      True
# SkyWest Airlines                     True
# French Bee                           True
# Alaska Airlines                     False
#                                     ...
# Trans States Airlines               False
# Boeing Company                      False
# Etihad Airways                      False
# Harmony Airways                     False
# Samsic Airport America, LLC         False
# Name: Operating Airline, Length: 125, dtype: bool

# %%
opv200_df=df2000["Operating Airline"].value_counts()

# %%
opv200_df.iloc[:10]
# Out:
# United Airlines - Pre 07/01/2013           803
# United Airlines                            703
# SkyWest Airlines                           292
# French Bee                                 257
# Alaska Airlines                            180
# Southwest Airlines                         165
# Aeroflot Russian International Airlines    112
# JetBlue Airways                            108
# Sun Country Airlines                       102
# Mesa Airlines                               92
# Name: Operating Airline, dtype: int64

# %%
df.groupby("Operating Airline").describe()
# Out:
#                                          Activity Period                 \
#                                                    count           mean
# Operating Airline
# ABC Aerolineas S.A. de C.V. dba Interjet            50.0  201878.360000
# ATA Airlines                                       271.0  200296.162362
# Aer Lingus, Ltd.                                   236.0  201601.355932
# Aeroflot Russian International Airlines            114.0  200143.421053
# Aeromexico                                         352.0  201570.659091
# ...                                                  ...            ...
# WestJet Airlines                                   227.0  201474.872247
# World Airways                                        5.0  200787.000000
# XL Airways France                                   65.0  201553.415385
# Xtra Airways                                         2.0  200608.000000
# ZIPAIR Tokyo Inc                                     6.0  202307.000000
#
# ...

# %%
df.groupby("Operating Airline").max()
# Out:
#                                           Activity Period  \
# Operating Airline
# ABC Aerolineas S.A. de C.V. dba Interjet           202003
# ATA Airlines                                       200802
# Aer Lingus, Ltd.                                   202308
# Aeroflot Russian International Airlines            200403
# Aeromexico                                         202308
# ...                                                   ...
# WestJet Airlines                                   202308
# World Airways                                      201211
# XL Airways France                                  201909
# Xtra Airways                                       200608
# ZIPAIR Tokyo Inc                                   202308
#
#                                          Activity Period Start Date  \
# Operating Airline
# ABC Aerolineas S.A. de C.V. dba Interjet                 2020/03/01
# ATA Airlines                                             2008/02/01
# ...

# %%
df.groupby("Operating Airline").max().plot()
# Out:
# <Axes: xlabel='Operating Airline'>
